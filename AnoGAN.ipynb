# %%
reset -f

# %%
# %matplotlib inline

import numpy as np

from anogan.anogan import AnoGAN

# %%
model = AnoGAN()

eval = model.train()

print(eval)
print(np.mean(eval), np.std(eval))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-cbd18ee9a81e> in <module>()
# ----> 1 model = AnoGAN()
#       2
#       3 eval = model.train()
#       4
#       5 print(eval)
#
# ~/AnoGAN-tf/anogan/anogan.py in __init__(self, name, training, D_lr, G_lr, in_shape, z_dim)
#      36
#      37         if training == True:
# ---> 38             self._build_train_graph()
#      39         else:
#      40             self._build_gen_graph()
#
# ~/AnoGAN-tf/anogan/anogan.py in _build_train_graph(self)
#      46             global_step = tf.Variable(0, name='global_step', trainable=False)
#      47
# ---> 48             G = self._generator(z)
#      49             D_real_prob, D_real_logits = self._discriminator(X)
#      50             D_fake_prob, D_fake_logits = self._discriminator(G, reuse=True)
#
# ~/AnoGAN-tf/anogan/anogan.py in _generator(self, z, reuse)
# ...
