# %%
reset -f

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from anogan.anogan import AnoGAN

# %%
tf.reset_default_graph()

REAL_MEAN = np.array([3.,4.])
REAL_COV = np.array([[1.,0.],[0.,1.]])
real_sample = np.random.multivariate_normal(REAL_MEAN, REAL_COV, size=100)

model = AnoGAN()
fake_sample = model.train()

model.anomaly_detector()
errors = model.train_anomaly_detector()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-55e559157ec7> in <module>()
#       8 fake_sample = model.train()
#       9
# ---> 10 model.anomaly_detector()
#      11 errors = model.train_anomaly_detector()
#
# ~/AnoGAN-tf/anogan/anogan.py in anomaly_detector(self, lambda_ano, reuse)
#     174         with tf.variable_scope('AnoD', reuse=reuse):
#     175             self.ano_z = tf.get_variable('ano_z', shape=[1, self.z_dim], dtype=tf.float32,
# --> 176                                         initializer=tf.random_uniform_initializer(-1, 1, dtype=tf.float32))
#     177
#     178         self.ano_G = self._generator(self.ano_z, reuse=True)
#
# ...

# %%
plt.scatter(fake_sample[0,:,0], fake_sample[0,:,1], c='b', alpha=0.7)
plt.scatter(real_sample[:,0], real_sample[:,1], c='g', alpha=0.7)
fake_sample.shape
# Out:
# (1, 100, 2)

# %%
fig = plt.figure()
ax = fig.gca()

sns.kdeplot(fake_sample[0,:,0], fake_sample[0,:,1], cmap='Blues', ax=ax)
sns.kdeplot(real_sample[:,0], real_sample[:,1], cmap='Greens', ax=ax)
